# %% [markdown]
# <a href="https://colab.research.google.com/github/jrlewis-umbc/MPLNET/blob/python/lineplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x = 23
print(x * 3)
